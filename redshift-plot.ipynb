# %%
# !pip install astropy
# !pip install IPython
# !pip install matplotlib
# !pip install numpy
# Out:
# Requirement already satisfied: astropy in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (6.0.0)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from astropy) (6.0.1)
# Requirement already satisfied: astropy-iers-data>=0.2023.10.30.0.29.53 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from astropy) (0.2024.2.19.0.28.47)
# Requirement already satisfied: numpy<2,>=1.22 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from astropy) (1.26.3)
# Requirement already satisfied: packaging>=19.0 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from astropy) (23.2)
# Requirement already satisfied: pyerfa>=2.0 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from astropy) (2.0.1.1)
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: IPython in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (8.21.0)
# Requirement already satisfied: decorator in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: traitlets>=5 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (5.14.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (0.6.3)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (3.0.43)
# Requirement already satisfied: exceptiongroup in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (1.2.0)
# Requirement already satisfied: colorama in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (0.4.6)
# Requirement already satisfied: matplotlib-inline in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (2.17.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from stack-data->IPython) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from stack-data->IPython) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from asttokens>=2.1.0->stack-data->IPython) (1.16.0)
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (3.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: pillow>=8 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\ryan\appdata\local\programs\python\python310\lib\site-packages (1.26.3)
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Set up matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from IPython.display import Image
Image(filename="ang_dist.png", width=500)

# %%
from astropy.cosmology import FlatLambdaCDM
import astropy.units as u

# In this case we just need to define the matter density 
# and hubble parameter at z=0.

# Note the default units for the hubble parameter H0 are km/s/Mpc. 
# We will pass in a `Quantity` object with the units specified. 

cosmo = FlatLambdaCDM(H0=70*u.km/u.s/u.Mpc, Om0=0.3)

# %%
import numpy as np
zvals = np.arange(0, 6, 0.1)
dist = cosmo.angular_diameter_distance(zvals)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[65], line 3
#       1 import numpy as np
#       2 zvals = np.arange(0, 6, 0.1)
# ----> 3 dist = cosmo.angular_diameter_distance(zvals)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\astropy\cosmology\flrw\base.py:1243, in FLRW.angular_diameter_distance(self, z)
#    1220 """Angular diameter distance in Mpc at a given redshift.
#    1221
#    1222 This gives the proper (sometimes called 'physical') transverse
#    (...)
#    1240 .. [3] Peebles, P. (1993). Principles of Physical Cosmology, pp 325-327.
#    1241 """
#    1242 z = aszarr(z)
# -> 1243 return self.comoving_transverse_distance(z) / (z + 1.0)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\astropy\cosmology\flrw\base.py:1184, in FLRW.comoving_transverse_distance(self, z)
#    1162 def comoving_transverse_distance(self, z):
#    1163     r"""Comoving transverse distance in Mpc at a given redshift.
#    1164
#    1165     This value is the transverse comoving distance at redshift ``z``
#    (...)
#    1182     This quantity is also called the 'proper motion distance' in some texts.
#    1183     """
# -> 1184     return self._comoving_transverse_distance_z1z2(0, z)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\astropy\cosmology\flrw\base.py:1209, in FLRW._comoving_transverse_distance_z1z2(self, z1, z2)
#    1187 r"""Comoving transverse distance in Mpc between two redshifts.
#    1188
#    1189 This value is the transverse comoving distance at redshift ``z2`` as
#    (...)
#    1206 This quantity is also called the 'proper motion distance' in some texts.
#    1207 """
#    1208 Ok0 = self._Ok0
# -> 1209 dc = self._comoving_distance_z1z2(z1, z2)
#    1210 if Ok0 == 0:
#    1211     return dc
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\astropy\cosmology\flrw\lambdacdm.py:383, in LambdaCDM._hypergeometric_comoving_distance_z1z2(self, z1, z2)
#     380 # Use np.sqrt here to handle negative s (Om0>1).
#     381 prefactor = self._hubble_distance / np.sqrt(s * self._Om0)
#     382 return prefactor * (
# --> 383     self._T_hypergeometric(s / (z1 + 1.0))
#     384     - self._T_hypergeometric(s / (z2 + 1.0))
#     385 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\astropy\cosmology\flrw\lambdacdm.py:407, in LambdaCDM._T_hypergeometric(self, x)
#     387 def _T_hypergeometric(self, x):
#     388     r"""Compute value using Gauss Hypergeometric function 2F1.
#     389
#     390     .. math::
#    (...)
#     405        in a flat cosmology. MNRAS, 468(1), 927-930.
#     406     """
# --> 407     return 2 * np.sqrt(x) * hyp2f1(1.0 / 6, 1.0 / 2, 7.0 / 6, -(x**3))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\astropy\cosmology\flrw\lambdacdm.py:25, in hyp2f1(*args, **kwargs)
#      24 def hyp2f1(*args, **kwargs):
# ---> 25     raise ModuleNotFoundError("No module named 'scipy.special'")
#
# ModuleNotFoundError: No module named 'scipy.special'
